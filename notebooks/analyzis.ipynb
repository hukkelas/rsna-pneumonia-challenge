# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab
import numpy as np
import pydicom
import pandas as pd
from glob import glob
import os
from matplotlib.patches import Rectangle

datapath = 'data/'

# %%
# !ls data/stage_1_train_images/ | wc
# Out:
#   25684   25684 1053044

# %%
df_box = pd.read_csv(datapath+'stage_1_train_labels.csv')
print('Number of rows (unique boxes per patient) in main train dataset:', df_box.shape[0])
print('Number of unique patient IDs:', df_box['patientId'].nunique())
df_box.head(6)
# Out:
# Number of rows (unique boxes per patient) in main train dataset: 28989
# Number of unique patient IDs: 25684
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1

# %%
df_box.groupby('Target').size().plot.bar()
print(df_box.groupby('Target').size() / df_box.shape[0])
# Out:
# Target
# 0    0.690779
# 1    0.309221
# dtype: float64

# %%
df_aux = pd.read_csv(datapath+'stage_1_detailed_class_info.csv')
print('Number of rows in auxiliary dataset:', df_aux.shape[0])
print('Number of unique patient IDs:', df_aux['patientId'].nunique())
df_aux.head(6)
# Out:
# Number of rows in auxiliary dataset: 28989
# Number of unique patient IDs: 25684
#                               patientId                         class
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6  No Lung Opacity / Not Normal
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd  No Lung Opacity / Not Normal
# 2  00322d4d-1c29-4943-afc9-b6754be640eb  No Lung Opacity / Not Normal
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5                        Normal
# 4  00436515-870c-4b36-a041-de91049b9ab4                  Lung Opacity
# 5  00436515-870c-4b36-a041-de91049b9ab4                  Lung Opacity

# %%
df_aux.groupby('class').size().plot.bar()
print(df_aux.groupby('class').size() / df_aux.shape[0])
assert df_box.loc[df_box['Target']==0].shape[0] == df_aux.loc[df_aux['class'].isin(['Normal', \
    'No Lung Opacity / Not Normal'])].shape[0], 'Number of negative targets does not match between main and auxiliary dataset.'
assert df_box.loc[df_box['Target']==1].shape[0] == df_aux.loc[df_aux['class'] == 'Lung Opacity'].shape[0], \
    'Number of positive targets does not match between main and auxiliary dataset.'
# Out:
# class
# Lung Opacity                    0.309221
# No Lung Opacity / Not Normal    0.396702
# Normal                          0.294077
# dtype: float64

# %%
assert df_box['patientId'].values.tolist() == df_aux['patientId'].values.tolist(), 'PatientId columns are different.'
df_train = pd.concat([df_box, df_aux.drop(labels=['patientId'], axis=1)], axis=1)
df_train.head(6)
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1
#
#                           class
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity
# 5                  Lung Opacity

# %%
df_train.groupby(['class', 'Target']).size()
# Out:
# class                         Target
# Lung Opacity                  1          8964
# No Lung Opacity / Not Normal  0         11500
# Normal                        0          8525
# dtype: int64

# %%
df_train.isnull().any()
# Out:
# patientId    False
# x             True
# y             True
# width         True
# height        True
# Target       False
# class        False
# dtype: bool

# %%
# when target==1, are any of the box coordinates null? (should all be false)
df_train.loc[df_train['Target']==1, ['x', 'y', 'width', 'height']].isnull().any()
# Out:
# x         False
# y         False
# width     False
# height    False
# dtype: bool

# %%
# when target==0, are all of the box coordinates null? (should all be true)
df_train.loc[df_train['Target']==0, ['x', 'y', 'width', 'height']].isnull().all()
# Out:
# x         True
# y         True
# width     True
# height    True
# dtype: bool

# %%
# sample of image filenames
# !ls -U data/stage_1_train_images/ | head -6
# Out:
# dce40126-49cb-444e-99fc-a5d5546569de.dcm
# d309f369-5cb4-4ad6-8b6b-316a1a973405.dcm
# 5f74d71f-3b73-4748-b7df-cc6374890c57.dcm
# 44da3869-4815-4f7c-9350-a396d9961443.dcm
# 582e641d-ac17-43b5-89a0-453555dd152e.dcm
# c490db79-e265-4196-9b80-f69278d197bc.dcm
# ls: write error: Broken pipe

# %%
# check that there is an image for each unique patient ID
assert sorted(df_train['patientId'].unique().tolist()) == sorted([f[:-4] for f in os.listdir(datapath+'stage_1_train_images/')]), \
    'Discrepancy between patient IDs and radiograph images.'

# %%
# have a look at the header meta-data of an image 
pId = df_train['patientId'].sample(1).values[0]    
dcmdata = pydicom.read_file(datapath+'stage_1_train_images/'+pId+'.dcm')
print(dcmdata)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.14528.1517874380.26212
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '3a010152-9ce2-4780-bdd8-bac6fa101991'
# (0010, 0020) Patient ID                          LO: '3a010152-9ce2-4780-bdd8-bac6fa101991'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '69'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.14528.1517874380.26211
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.14528.1517874380.26210
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.139', '0.139']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 138506 bytes

# %%
# extract the raw pixel image and look at its properties
dcmimg = dcmdata.pixel_array
print(type(dcmimg))
print(dcmimg.dtype)
print(dcmimg.shape)
# Out:
# <class 'numpy.ndarray'>
# uint8
# (1024, 1024)

# %%
# visualize the corresponding radiograph image
plt.figure(figsize=(20,10))
plt.imshow(dcmimg, cmap=pylab.cm.binary)
plt.axis('off')
# Out:
# (-0.5, 1023.5, 1023.5, -0.5)

# %%
def get_boxes_per_patient(df, pId):
    '''
    Given the dataset and one patient ID, 
    return an array of all the bounding boxes and their labels associated with that patient ID.
    Example of return: 
    array([[x1, y1, width1, height1, class1, target1],
           [x2, y2, width2, height2, class2, target2]])
    '''
    
    boxes = df.loc[df['patientId']==pId][['x', 'y', 'width', 'height', 'class', 'Target']].values
    return boxes

# %%
def get_dcm_data_per_patient(pId, sample='train'):
    '''
    Given one patient ID and the sample name (train/test), 
    return the corresponding dicom data.
    '''
    return pydicom.read_file(datapath+'stage_1_'+sample+'_images/'+pId+'.dcm')

# %%
def display_image_per_patient(df, pId, angle=0.0, sample='train'):
    '''
    Given one patient ID and the dataset,
    display the corresponding dicom image with overlaying boxes and class annotation.
    To be implemented: Optionally input the image rotation angle, in case of data augmentation.
    '''
    dcmdata = get_dcm_data_per_patient(pId, sample=sample)
    dcmimg = dcmdata.pixel_array
    boxes = get_boxes_per_patient(df, pId)
    plt.figure(figsize=(20,10))
    plt.imshow(dcmimg, cmap=pylab.cm.binary)
    plt.axis('off')
    
    class_color_dict = {'Normal' : 'green',
                        'No Lung Opacity / Not Normal' : 'orange',
                        'Lung Opacity' : 'red'}

    if len(boxes)>0:
        for box in boxes:
            # extracting individual coordinates and labels
            x, y, w, h, c, t = box 
            # create a rectangle patch
            patch = Rectangle((x,y), w, h, color='red', 
                              angle=angle, fill=False, lw=4, joinstyle='round', alpha=0.6)
            # get current axis and draw rectangle
            plt.gca().add_patch(patch)
            
    # add annotation text
    plt.text(10, 50, c, color=class_color_dict[c], size=20, 
             bbox=dict(edgecolor=class_color_dict[c], facecolor='none', alpha=0.5, lw=2))

# %%
pId
# Out:
# '6365ff26-72cf-4428-8610-66aab9c787c9'

# %%
# run this cell multiple times to visualize different examples
pId = df_train['patientId'].sample(1).values[0]    
display_image_per_patient(df_train, pId, sample='train')

# %%
def get_metadata_per_patient(pId, attribute, sample='train'):
    '''
    Given a patient ID, return useful meta-data from the corresponding dicom image header.
    Return: 
    attribute value
    '''
    # get dicom image
    dcmdata = get_dcm_data_per_patient(pId, sample=sample)
    # extract attribute values
    attribute_value = getattr(dcmdata, attribute)
    return attribute_value

# %%
df_train
# Out:
#                                   patientId      x      y  width  height  \
# 0      0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN
# 1      00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN
# 2      00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN
# 3      003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN
# 4      00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0
# 5      00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0
# 6      00569f44-917d-4c86-a842-81832af98c30    NaN    NaN    NaN     NaN
# 7      006cec2e-6ce2-4549-bffa-eadfcd1e9970    NaN    NaN    NaN     NaN
# 8      00704310-78a8-4b38-8475-49f4573b2dbb  323.0  577.0  160.0   104.0
# 9      00704310-78a8-4b38-8475-49f4573b2dbb  695.0  575.0  162.0   137.0
# 10     008c19e8-a820-403a-930a-bc74a4053664    NaN    NaN    NaN     NaN
# 11     009482dc-3db5-48d4-8580-5c89c4f01334    NaN    NaN    NaN     NaN
# 12     009eb222-eabc-4150-8121-d5a6d06b8ebf    NaN    NaN    NaN     NaN
# 13     00a85be6-6eb0-421d-8acf-ff2dc0007e8a    NaN    NaN    NaN     NaN
# 14     00aecb01-a116-45a2-956c-08d2fa55433f  288.0  322.0   94.0   135.0
# 15     00aecb01-a116-45a2-956c-08d2fa55433f  547.0  299.0  119.0   165.0
# 16     00c0b293-48e7-4e16-ac76-9269ba535a62  306.0  544.0  168.0   244.0
# 17     00c0b293-48e7-4e16-ac76-9269ba535a62  650.0  511.0  206.0   284.0
# 18     00d7c36e-3cdf-4df6-ac03-6c30cdc8e85b    NaN    NaN    NaN     NaN
# 19     00f08de1-517e-4652-a04f-d1dc9ee48593  181.0  184.0  206.0   506.0
# 20     00f08de1-517e-4652-a04f-d1dc9ee48593  571.0  275.0  230.0   476.0
# 21     00f87de5-5fe0-4921-93ea-914d7e683266    NaN    NaN    NaN     NaN
# 22     0100515c-5204-4f31-98e0-f35e4b00004a  703.0  416.0   84.0    77.0
# 23     01027bc3-dc40-4165-a6c3-d6be2cb7ca34    NaN    NaN    NaN     NaN
# 24     010ccb9f-6d46-4380-af11-84f87397a1b8  652.0  437.0  161.0   293.0
# 25     010ccb9f-6d46-4380-af11-84f87397a1b8  301.0  405.0  141.0   279.0
# 26     011d6f51-b732-4d45-a84d-90477325ef2d    NaN    NaN    NaN     NaN
# 27     012a5620-d082-4bb8-9b3b-e72d8938000c  133.0  613.0  275.0   275.0
# 28     012a5620-d082-4bb8-9b3b-e72d8938000c  678.0  427.0  224.0   340.0
# 29     014b7b58-f641-4477-8bbc-ae6f337745d6    NaN    NaN    NaN     NaN
# ...                                     ...    ...    ...    ...     ...
# 28959  ffc9e552-ca53-43a8-a156-b0f97f0d40f3    NaN    NaN    NaN     NaN
# 28960  ffcc35e8-6fe8-42df-9605-9fedf57240d1    NaN    NaN    NaN     NaN
# 28961  ffcfe8c1-5641-4dc3-910c-573e3227f536    NaN    NaN    NaN     NaN
# 28962  ffd0c212-bfb6-41e3-b17b-b927b99d1730    NaN    NaN    NaN     NaN
# 28963  ffd2bc74-f9d6-49fb-84d7-de060ee22583    NaN    NaN    NaN     NaN
# 28964  ffd56560-6754-4a20-83c6-06ad5c4b30ab    NaN    NaN    NaN     NaN
# 28965  ffd670a5-b6dc-4f54-928a-69b7a04662eb    NaN    NaN    NaN     NaN
# 28966  ffd787b6-59ca-48cb-bd15-bcedd52cf37c  157.0  393.0  237.0   458.0
# 28967  ffd787b6-59ca-48cb-bd15-bcedd52cf37c  571.0  238.0  286.0   482.0
# 28968  ffdc771e-1f1a-47f7-b732-3e06e48c24e8    NaN    NaN    NaN     NaN
# 28969  ffdc8a6a-f513-4a04-9c1d-24840a779220    NaN    NaN    NaN     NaN
# 28970  ffdc957e-6239-427d-8a54-fdf8ced3a356    NaN    NaN    NaN     NaN
# 28971  ffde3879-241c-4b03-9d91-625cae6b49e8    NaN    NaN    NaN     NaN
# 28972  ffde3e7e-849c-4077-bfd0-4e4498ee8817    NaN    NaN    NaN     NaN
# 28973  ffe16061-b19f-4333-8a03-b41aab42b47d    NaN    NaN    NaN     NaN
# 28974  ffe4707d-517c-4ed0-8a9f-3ad149748991    NaN    NaN    NaN     NaN
# 28975  ffe9a1c4-634d-408f-9b0f-8098ffb78a4e    NaN    NaN    NaN     NaN
# 28976  ffe9ab5c-9d39-4235-9ade-d725dcad6b76    NaN    NaN    NaN     NaN
# 28977  ffeab8ae-f339-40d6-96f1-f1f8c97d2cb1    NaN    NaN    NaN     NaN
# 28978  ffee0360-20cf-4d4a-9af5-e5c9b493c73b    NaN    NaN    NaN     NaN
# 28979  fff0b503-72a5-446a-843d-f3d152e39053  158.0  267.0  180.0   209.0
# 28980  fff1cc9c-3895-43be-84e1-a7aaef21002b    NaN    NaN    NaN     NaN
# 28981  fff50447-821b-4b72-ae91-22b0679d6d3e    NaN    NaN    NaN     NaN
# 28982  fff7447f-99ce-4102-87f3-9788b2459eb4    NaN    NaN    NaN     NaN
# 28983  fffb2395-8edd-4954-8a89-ffe2fd329be3  177.0  285.0  225.0   529.0
# 28984  fffb2395-8edd-4954-8a89-ffe2fd329be3  641.0  473.0  201.0   309.0
# 28985  fffba05a-1635-4545-9bbd-57ad4cfe8d27    NaN    NaN    NaN     NaN
# 28986  fffc95b5-605b-4226-80ab-62caec682b22    NaN    NaN    NaN     NaN
# 28987  fffcff11-d018-4414-971a-a7cefa327795    NaN    NaN    NaN     NaN
# 28988  fffec09e-8a4a-48b1-b33e-ab4890ccd136    NaN    NaN    NaN     NaN
#
#        Target                         class
# 0           0  No Lung Opacity / Not Normal
# 1           0  No Lung Opacity / Not Normal
# 2           0  No Lung Opacity / Not Normal
# 3           0                        Normal
# 4           1                  Lung Opacity
# 5           1                  Lung Opacity
# 6           0  No Lung Opacity / Not Normal
# 7           0  No Lung Opacity / Not Normal
# 8           1                  Lung Opacity
# 9           1                  Lung Opacity
# 10          0  No Lung Opacity / Not Normal
# 11          0                        Normal
# 12          0                        Normal
# 13          0                        Normal
# 14          1                  Lung Opacity
# 15          1                  Lung Opacity
# 16          1                  Lung Opacity
# 17          1                  Lung Opacity
# 18          0  No Lung Opacity / Not Normal
# 19          1                  Lung Opacity
# 20          1                  Lung Opacity
# 21          0                        Normal
# 22          1                  Lung Opacity
# 23          0                        Normal
# 24          1                  Lung Opacity
# 25          1                  Lung Opacity
# 26          0  No Lung Opacity / Not Normal
# 27          1                  Lung Opacity
# 28          1                  Lung Opacity
# 29          0  No Lung Opacity / Not Normal
# ...       ...                           ...
# 28959       0                        Normal
# 28960       0                        Normal
# 28961       0  No Lung Opacity / Not Normal
# 28962       0  No Lung Opacity / Not Normal
# 28963       0  No Lung Opacity / Not Normal
# 28964       0                        Normal
# 28965       0  No Lung Opacity / Not Normal
# 28966       1                  Lung Opacity
# 28967       1                  Lung Opacity
# 28968       0  No Lung Opacity / Not Normal
# 28969       0                        Normal
# 28970       0  No Lung Opacity / Not Normal
# 28971       0  No Lung Opacity / Not Normal
# 28972       0  No Lung Opacity / Not Normal
# 28973       0                        Normal
# 28974       0  No Lung Opacity / Not Normal
# 28975       0  No Lung Opacity / Not Normal
# 28976       0  No Lung Opacity / Not Normal
# 28977       0  No Lung Opacity / Not Normal
# 28978       0  No Lung Opacity / Not Normal
# 28979       1                  Lung Opacity
# 28980       0  No Lung Opacity / Not Normal
# 28981       0                        Normal
# 28982       0  No Lung Opacity / Not Normal
# 28983       1                  Lung Opacity
# 28984       1                  Lung Opacity
# 28985       0                        Normal
# 28986       0  No Lung Opacity / Not Normal
# 28987       0  No Lung Opacity / Not Normal
# 28988       0  No Lung Opacity / Not Normal
#
# [28989 rows x 7 columns]

# %%
# create list of attributes that we want to extract (manually edited after checking which attributes contained valuable information)
attributes = ['PatientSex', 'PatientAge', 'ViewPosition']
for a in attributes:
    df_train[a] = df_train['patientId'].apply(lambda x: get_metadata_per_patient(x, a, sample='train'))
# convert patient age from string to numeric
df_train['PatientAge'] = df_train['PatientAge'].apply(pd.to_numeric, errors='coerce')
# remove a few outliers
df_train['PatientAge'] = df_train['PatientAge'].apply(lambda x: x if x<120 else np.nan)
df_train.head()
# Out:
# PatientSex
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-17826000cf6a> in <module>()
#       3 for a in attributes:
#       4     print(a)
# ----> 5     df_train[a] = df_train['patientId'].apply(lambda x: get_metadata_per_patient(x, a, sample='train'))
#       6 # convert patient age from string to numeric
#       7 df_train['PatientAge'] = df_train['PatientAge'].apply(pd.to_numeric, errors='coerce')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-26-17826000cf6a> in <lambda>(x)
#       3 for a in attributes:
#       4     print(a)
# ----> 5     df_train[a] = df_train['patientId'].apply(lambda x: get_metadata_per_patient(x, a, sample='train'))
#       6 # convert patient age from string to numeric
#       7 df_train['PatientAge'] = df_train['PatientAge'].apply(pd.to_numeric, errors='coerce')
#
# <ipython-input-23-b0d4616589ac> in get_metadata_per_patient(pId, attribute, sample)
#       6     '''
#       7     # get dicom image
# ----> 8     dcmdata = get_dcm_data_per_patient(pId, sample=sample)
#       9     # extract attribute values
#      10     attribute_value = getattr(dcmdata, attribute)
#
# <ipython-input-19-fec45f5da1a9> in get_dcm_data_per_patient(pId, sample)
#       4     return the corresponding dicom data.
#       5     '''
# ----> 6     return pydicom.read_file(datapath+'stage_1_'+sample+'_images/'+pId+'.dcm')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     860         except Exception:
#     861             logger.debug("Reading file '{0}'".format(fp))
# --> 862         fp = open(fp, 'rb')
#     863
#     864     if config.debugging:
#
# KeyboardInterrupt:
